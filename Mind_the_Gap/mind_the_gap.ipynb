# %%
import pandas as pd
import requests
from datetime import datetime
import matplotlib.pyplot as plt

# %%
response2008 = []
for i in range(1, 19):
    link = 'http://ergast.com/api/f1/2008/' + str(i) + '/driverStandings.json'
    response2008.append(requests.get(link).json())
lead_score = [0]
HAM_score = [0]
MAS_score = [0,0,0]

for response in response2008:
    lead_score.append(response['MRData']['StandingsTable']['StandingsLists'][0]['DriverStandings'][0]['points'])
    for standing in response['MRData']['StandingsTable']['StandingsLists'][0]['DriverStandings']:
        if standing['Driver']['code'] == "HAM":
            HAM_score.append(standing['points'])
        if standing['Driver']['code'] == "MAS":
            MAS_score.append(standing['points'])


response2008quali = []
for i in range(1, 19):
    link = 'http://ergast.com/api/f1/2008/' + str(i) + '/qualifying.json'
    response2008quali.append(requests.get(link).json())
circuit08 = []
lead_quali08 = []
P5 = []
HAM_quali = []
MAS_quali = []
for response in response2008quali:
    circuit08.append(response['MRData']['RaceTable']['Races'][0]['raceName'])
    lead_quali08.append(response['MRData']['RaceTable']['Races'][0]['QualifyingResults'][0]['Q3'])
    P5.append(response['MRData']['RaceTable']['Races'][0]['QualifyingResults'][4]['Q3']) #Q2
    for quali in response['MRData']['RaceTable']['Races'][0]['QualifyingResults']:
        if quali['Driver']['code'] == 'MAS':
            if 'Q3' in quali:
                MAS_quali.append(quali['Q3'])
            else:
                MAS_quali.append(100)
        if quali['Driver']['code'] == 'HAM':
            if 'Q3' in quali:
                HAM_quali.append(quali['Q3'])
            else:
                HAM_quali.append(int(quali['position']))

df_2008 = pd.DataFrame(list(zip(circuit08, lead_score, HAM_score, MAS_score, lead_quali08, P5, HAM_quali, MAS_quali)), columns = ['Circuit', 'Leading Score', 'HAM Score', 'MAS Score', 'Fastest Quali', 'P5 Quali', 'HAM Quali', 'MAS Quali'])
df_2008['Year'] = 2008
df_2008.at[13, 'HAM Quali'] = '1:41.212'
df_2008.head(18)
# Out:
#                   Circuit Leading Score HAM Score MAS Score Fastest Quali  \
# 0   Australian Grand Prix             0         0         0      1:26.714
# 1    Malaysian Grand Prix            10        10         0      1:35.748
# 2      Bahrain Grand Prix            14        14         0      1:33.096
# 3      Spanish Grand Prix            19        14        10      1:21.813
# 4      Turkish Grand Prix            29        20        18      1:27.617
# 5       Monaco Grand Prix            35        28        28      1:15.787
# 6     Canadian Grand Prix            38        38        34      1:17.886
# 7       French Grand Prix            42        38        38      1:16.449
# 8      British Grand Prix            48        38        48      1:21.049
# 9       German Grand Prix            48        48        48      1:15.666
# 10   Hungarian Grand Prix            58        58        54      1:20.899
# 11    European Grand Prix            62        62        54      1:38.989
# ...

# %% [markdown]
# HAM did not make Q3 in Monza, input

# %%
response2012 = []
for i in range(1, 21):
    link = 'http://ergast.com/api/f1/2012/' + str(i) + '/driverStandings.json'
    response2012.append(requests.get(link).json())
lead_score12 = [0]
VET_score = [0]
ALO_score = [0]

for response in response2012:
    lead_score12.append(response['MRData']['StandingsTable']['StandingsLists'][0]['DriverStandings'][0]['points'])
    for standing in response['MRData']['StandingsTable']['StandingsLists'][0]['DriverStandings']:
        if standing['Driver']['code'] == "VET":
            VET_score.append(standing['points'])
        if standing['Driver']['code'] == "ALO":
            ALO_score.append(standing['points'])


response2012quali = []
for i in range(1, 21):
    link = 'http://ergast.com/api/f1/2012/' + str(i) + '/qualifying.json'
    response2012quali.append(requests.get(link).json())
circuit12 = []
lead_quali12 = []
P5_2012 = []
VET_quali = []
ALO_quali = []
for response in response2012quali:
    circuit12.append(response['MRData']['RaceTable']['Races'][0]['raceName'])
    lead_quali12.append(response['MRData']['RaceTable']['Races'][0]['QualifyingResults'][0]['Q3'])
    P5_2012.append(response['MRData']['RaceTable']['Races'][0]['QualifyingResults'][4]['Q3']) #Q2
    for quali in response['MRData']['RaceTable']['Races'][0]['QualifyingResults']:
        if quali['Driver']['code'] == 'VET':
            if 'Q3' in quali:
                VET_quali.append(quali['Q3'])
            else:
                VET_quali.append(int(quali['position']))

        if quali['Driver']['code'] == 'ALO':
            if 'Q3' in quali:
                ALO_quali.append(quali['Q3'])
            else:
                #ALO_quali.append(100)
                ALO_quali.append(int(quali['position']))


df_2012 = pd.DataFrame(list(zip(circuit12, lead_score12, VET_score, ALO_score, lead_quali12, P5_2012, VET_quali, ALO_quali)), columns = ['Circuit', 'Leading Score', 'VET Score', 'ALO Score', 'Fastest Quali', 'P5 Quali', 'VET Quali', 'ALO Quali'])
df_2012['Year'] = 2012
df_2012.at[0, 'ALO Quali'] = '1:27.024'
df_2012.at[2, 'VET Quali'] = '1:36.997'
df_2012.at[3, 'ALO Quali'] = '1:33.533'
df_2012.at[4, 'VET Quali'] = '1:23.221'
df_2012.at[5, 'VET Quali'] = '1:15.363'
df_2012.at[7, 'ALO Quali'] = '1:39.093'
df_2012.at[11, 'VET Quali'] = '1:49.036'
df_2012.head(20)
# Out:
#                      Circuit Leading Score VET Score ALO Score Fastest Quali  \
# 0      Australian Grand Prix             0         0         0      1:24.922
# 1       Malaysian Grand Prix            25        18        10      1:36.219
# 2         Chinese Grand Prix            35        18        35      1:35.121
# 3         Bahrain Grand Prix            45        28        37      1:32.422
# 4         Spanish Grand Prix            53        53        43      1:21.707
# 5          Monaco Grand Prix            61        61        61      1:14.301
# 6        Canadian Grand Prix            76        73        76      1:13.784
# 7        European Grand Prix            88        85        86      1:38.086
# 8         British Grand Prix           111        85       111      1:51.746
# 9          German Grand Prix           129       100       129      1:40.621
# 10      Hungarian Grand Prix           154       110       154      1:20.953
# ...

# %% [markdown]
# ALO Australia, VET China, ALO Bahrain, VET Spain, Monaco VET, ALO Europe, VET Spa missed Q3

# %%
response2016 = []
for i in range(1, 22):
    link = 'http://ergast.com/api/f1/2016/' + str(i) + '/driverStandings.json'
    response2016.append(requests.get(link).json())
lead_score16 = [0]
ROS_score = [0]
HAM2_score = [0]

for response in response2016:
    lead_score16.append(response['MRData']['StandingsTable']['StandingsLists'][0]['DriverStandings'][0]['points'])
    for standing in response['MRData']['StandingsTable']['StandingsLists'][0]['DriverStandings']:
        if standing['Driver']['code'] == "ROS":
            ROS_score.append(standing['points'])
        if standing['Driver']['code'] == "HAM":
            HAM2_score.append(standing['points'])


response2016quali = []
for i in range(1, 22):
    link = 'http://ergast.com/api/f1/2016/' + str(i) + '/qualifying.json'
    response2016quali.append(requests.get(link).json())
circuit16 = []
lead_quali16 = []
P5_2016 = []
ROS_quali = []
HAM2_quali = []
for response in response2016quali:
    circuit16.append(response['MRData']['RaceTable']['Races'][0]['raceName'])
    lead_quali16.append(response['MRData']['RaceTable']['Races'][0]['QualifyingResults'][0]['Q3'])
    P5_2016.append(response['MRData']['RaceTable']['Races'][0]['QualifyingResults'][4]['Q3']) #Q2
    for quali in response['MRData']['RaceTable']['Races'][0]['QualifyingResults']:
        if quali['Driver']['code'] == 'ROS':
            if 'Q3' in quali:
                ROS_quali.append(quali['Q3'])
            else:
                ROS_quali.append(int(quali['position']))
        if quali['Driver']['code'] == 'HAM':
            if 'Q3' in quali:
                HAM2_quali.append(quali['Q3'])
            else:
                HAM2_quali.append(int(quali['position']))

df_2016 = pd.DataFrame(list(zip(circuit16, lead_score16, ROS_score, HAM2_score, lead_quali16, P5_2016, ROS_quali, HAM2_quali)), columns = ['Circuit', 'Leading Score', 'ROS Score', 'HAM2 Score', 'Fastest Quali', 'P5 Quali', 'ROS Quali', 'HAM2 Quali'])
df_2016.at[2, 'HAM2 Quali'] = None
df_2016.at[3, 'HAM2 Quali'] = None
df_2016.at[12, 'HAM2 Quali'] = None
df_2016.head(21)
# Out:
#                      Circuit Leading Score ROS Score HAM2 Score Fastest Quali  \
# 0      Australian Grand Prix             0         0          0      1:23.837
# 1         Bahrain Grand Prix            25        25         18      1:29.493
# 2         Chinese Grand Prix            50        50         33      1:35.402
# 3         Russian Grand Prix            75        75         39      1:35.417
# 4         Spanish Grand Prix           100       100         57      1:22.000
# 5          Monaco Grand Prix           100       100         57      1:13.622
# 6        Canadian Grand Prix           106       106         82      1:12.812
# 7        European Grand Prix           116       116        107      1:42.758
# 8        Austrian Grand Prix           141       141        117      1:07.922
# 9         British Grand Prix           153       153        142      1:29.287
# 10      Hungarian Grand Prix           168       168        167      1:19.965
# ...

# %% [markdown]
# HAM2 China, Russia, Spa input (all reliability issues)

# %%
def dt_to_int(time):
    return 1000*time.seconds + time.milliseconds

# %%
df_2008['Leading Score'] = df_2008['Leading Score'].astype(float)
df_2008['HAM Score'] = df_2008['HAM Score'].astype(float)
df_2008['MAS Score'] = df_2008['MAS Score'].astype(float)
# df_2008['Fastest Quali'] = pd.to_datetime(df_2008['Fastest Quali'], format='%H:%M:%S.%f').dt.time
# df_2008['MAS Quali'] = pd.to_datetime(df_2008['MAS Quali'], format='%H:%M:%S.%f')
# df_2008['MAS Quali'] - dt_to_int(df_2008['MAS Quali'])
MAS_Quali_Gap = []
for i in range(len(df_2008)):
    MAS_Quali_Gap.append(datetime.strptime(df_2008['MAS Quali'][i], '%M:%S.%f') - datetime.strptime(df_2008['Fastest Quali'][i], '%M:%S.%f'))
#df_2008['MAS Quali Gap'] = datetime.strptime(df_2008['MAS Quali'], '%M:%S.%f') - datetime.strptime(df_2008['Fastest Quali'], '%M:%S.%f')
df_2008['MAS Quali Gap'] = MAS_Quali_Gap
df_2008['MAS Quali Gap'] = df_2008['MAS Quali Gap'].dt.total_seconds()
HAM_Quali_Gap = []
for i in range(len(df_2008)):
    HAM_Quali_Gap.append(datetime.strptime(df_2008['HAM Quali'][i], '%M:%S.%f') - datetime.strptime(df_2008['Fastest Quali'][i], '%M:%S.%f'))
df_2008['HAM Quali Gap'] = HAM_Quali_Gap
df_2008['HAM Quali Gap'] = df_2008['HAM Quali Gap'].dt.total_seconds()
df_2008['HAM Gap'] = df_2008['HAM Score'] - df_2008['Leading Score']
df_2008['MAS Gap'] = df_2008['MAS Score'] - df_2008['Leading Score']
# df_2008['HAM Quali Gap'] = df_2008['Fastest Quali'] - df_2008['HAM Quali']
# df_2008['MAS Quali Gap'] = df_2008['Fastest Quali'] - df_2008['MAS Quali']
# df_2008['MAS Quali Gap'] = (pd.to_datetime(df_2008['MAS Quali'].astype(str), format='%H:%M:%S.%f') -
#    pd.to_datetime(df_2008['Fastest Quali'].astype(str), format='%H:%M:%S.%f')).dt.time


df_2012['Leading Score'] = df_2012['Leading Score'].astype(float)
df_2012['VET Score'] = df_2012['VET Score'].astype(float)
df_2012['ALO Score'] = df_2012['ALO Score'].astype(float)
VET_Quali_Gap = []
for i in range(len(df_2012)):
    VET_Quali_Gap.append(datetime.strptime(df_2012['VET Quali'][i], '%M:%S.%f') - datetime.strptime(df_2012['Fastest Quali'][i], '%M:%S.%f'))
df_2012['VET Quali Gap'] = VET_Quali_Gap
df_2012['VET Quali Gap'] = df_2012['VET Quali Gap'].dt.total_seconds()
ALO_Quali_Gap = []
for i in range(len(df_2012)):
    ALO_Quali_Gap.append(datetime.strptime(df_2012['ALO Quali'][i], '%M:%S.%f') - datetime.strptime(df_2012['Fastest Quali'][i], '%M:%S.%f'))
df_2012['ALO Quali Gap'] = ALO_Quali_Gap
df_2012['ALO Quali Gap'] = df_2012['ALO Quali Gap'].dt.total_seconds()
df_2012['VET Gap'] = df_2012['VET Score'] - df_2012['Leading Score']
df_2012['ALO Gap'] = df_2012['ALO Score'] - df_2012['Leading Score']
# df_2012['VET Quali Gap'] = df_2012['Fastest Quali'] - df_2012['VET Quali']
# df_2012['ALO Quali Gap'] = df_2012['Fastest Quali'] - df_2012['ALO Quali']

df_2016['Leading Score'] = df_2016['Leading Score'].astype(float)
df_2016['ROS Score'] = df_2016['ROS Score'].astype(float)
df_2016['HAM2 Score'] = df_2016['HAM2 Score'].astype(float)
ROS_Quali_Gap = []
for i in range(len(df_2016)):
    ROS_Quali_Gap.append(datetime.strptime(df_2016['ROS Quali'][i], '%M:%S.%f') - datetime.strptime(df_2016['Fastest Quali'][i], '%M:%S.%f'))
df_2016['ROS Quali Gap'] = ROS_Quali_Gap
df_2016['ROS Quali Gap'] = df_2016['ROS Quali Gap'].dt.total_seconds()
HAM2_Quali_Gap = []
for i in range(len(df_2016)):
    if df_2016['HAM2 Quali'][i] == None:
        HAM2_Quali_Gap.append(None)
    else:
        HAM2_Quali_Gap.append(datetime.strptime(df_2016['HAM2 Quali'][i], '%M:%S.%f') - datetime.strptime(df_2016['Fastest Quali'][i], '%M:%S.%f'))
df_2016['HAM2 Quali Gap'] = HAM2_Quali_Gap
df_2016['HAM2 Quali Gap'] = df_2016['HAM2 Quali Gap'].dt.total_seconds()
df_2016['ROS Gap'] = df_2016['ROS Score'] - df_2016['Leading Score']
df_2016['HAM2 Gap'] = df_2016['HAM2 Score'] - df_2016['Leading Score']
# df_2016['ROS Quali Gap'] = df_2016['Fastest Quali'] - df_2016['ROS Quali']
# df_2016['HAM2 Quali Gap'] = df_2016['Fastest Quali'] - df_2016['HAM2 Quali']

# %%
df_2008.head()
# Out:
#                  Circuit  Leading Score  HAM Score  MAS Score Fastest Quali  \
# 0  Australian Grand Prix            0.0        0.0        0.0      1:26.714
# 1   Malaysian Grand Prix           10.0       10.0        0.0      1:35.748
# 2     Bahrain Grand Prix           14.0       14.0        0.0      1:33.096
# 3     Spanish Grand Prix           19.0       14.0       10.0      1:21.813
# 4     Turkish Grand Prix           29.0       20.0       18.0      1:27.617
#
#    P5 Quali HAM Quali MAS Quali  Year  MAS Quali Gap  HAM Quali Gap  HAM Gap  \
# 0  1:27.236  1:26.714  1:27.178  2008          0.464          0.000      0.0
# 1  1:36.711  1:36.709  1:35.748  2008          0.000          0.961      0.0
# 2  1:33.488  1:33.292  1:33.123  2008          0.027          0.196      0.0
# 3  1:22.096  1:22.096  1:22.058  2008          0.245          0.283     -5.0
# 4  1:28.390  1:27.923  1:27.617  2008          0.000          0.306     -9.0
#
#    MAS Gap
# 0      0.0
# 1    -10.0
# ...

# %%
df_2008[['HAM Gap', 'HAM Quali Gap']].corr()
# Out:
#                 HAM Gap  HAM Quali Gap
# HAM Gap        1.000000       0.036518
# HAM Quali Gap  0.036518       1.000000

# %%
df_2008[['MAS Gap', 'MAS Quali Gap']].corr()
# Out:
#                 MAS Gap  MAS Quali Gap
# MAS Gap        1.000000       0.509756
# MAS Quali Gap  0.509756       1.000000

# %%
#2008 Viz
fig = plt.figure(figsize=(15,25))
fig.set_facecolor('#3e3e3e')
ax1 = fig.add_subplot(4, 1, 1)
plt.plot( 'Circuit', 'HAM Score', data=df_2008, marker = 'o', color='grey', linewidth=2)
plt.plot( 'Circuit', 'MAS Score', data=df_2008, marker = 'o', color='firebrick', linewidth=2)
plt.title('2008 F1 Championship Battle, Hamilton vs. Massa', fontsize = 24, color = 'white')
plt.xlabel('Grand Prix', fontsize = 19, color = 'white')
plt.ylabel('Championship Points', fontsize = 19, color = 'white')
ax1.legend()
plt.xticks(rotation=90, color = 'white', fontsize = 12)
plt.yticks(color = 'white')
ax1.set_facecolor('gainsboro')
ax1.grid(which = 'major', axis = 'y', linewidth = 1, color = 'white', alpha = 0.9)

ax2 = fig.add_subplot(5, 1, 3)
plt.plot( 'Circuit', 'HAM Gap', data=df_2008, marker = 'o', color='grey', linewidth=2)
ax2.set_facecolor('gainsboro')
plt.xticks(rotation=90, color = 'white', fontsize = 12)
plt.title('Points Behind Championship Lead and Gap to Pole (HAM)', fontsize = 24, color = 'white')
plt.xlabel('Grand Prix', fontsize = 19, color = 'white')
plt.ylabel('Championship Points Behind', fontsize = 12, color = 'white')
plt.yticks(color = 'white')
ax2.legend(loc = 'center left', bbox_to_anchor=(0, 0.6))
ax3 = ax2.twinx()
ax3.plot('Circuit', 'HAM Quali Gap', data=df_2008, marker = 'o', color = 'darkorange')
plt.yticks(color = 'white')
plt.ylabel('Gap to Pole (in seconds)', fontsize = 12, color = 'white')
ax3.legend(loc = 'center left', bbox_to_anchor=(0, 0.52))

ax4 = fig.add_subplot(5,1,5)
plt.plot( 'Circuit', 'MAS Gap', data=df_2008, marker = 'o', color='#D40000', linewidth=2)
ax4.set_facecolor('gainsboro')
plt.xticks(rotation=90, color = 'white', fontsize = 12)
plt.title('Points Behind Championship Lead and Gap to Pole (MAS)', fontsize = 24, color = 'white')
plt.xlabel('Grand Prix', fontsize = 19, color = 'white')
plt.ylabel('Championship Points Behind', fontsize = 12, color = 'white')
plt.yticks(color = 'white')
ax4.legend(loc = 'center left', bbox_to_anchor=(0, 0.6))
ax5 = ax4.twinx()
ax5.plot('Circuit', 'MAS Quali Gap', data=df_2008, marker = 'o', color = '#fffa00')
plt.yticks(color = 'white')
plt.ylabel('Gap to Pole (in seconds)', fontsize = 12, color = 'white')
ax5.legend(loc = 'center left', bbox_to_anchor=(0, 0.52))

# %%
#2008 Viz Continuation
fig = plt.figure(figsize = (15,9))
ax1 = fig.add_subplot(2, 2, 1)
plt.scatter(df_2008['HAM Gap'], df_2008['HAM Quali Gap'], color = 'grey')
plt.title('WDC Gap vs. Quali Gap (HAM)', fontsize = 19, color = 'black')
plt.xlabel('Points behind WDC Lead', fontsize = 15, color = 'black')
plt.ylabel('Gap to Pole (in seconds)', fontsize = 15, color = 'black')
ax1.set_facecolor('gainsboro')

ax2 = fig.add_subplot(2, 2, 2)
plt.scatter(df_2008['MAS Gap'], df_2008['MAS Quali Gap'], color = 'firebrick')
plt.title('WDC Gap vs. Quali Gap (MAS)', fontsize = 19, color = 'black')
plt.xlabel('Points behind WDC Lead', fontsize = 15, color = 'black')
plt.ylabel('Gap to Pole (in seconds)', fontsize = 15, color = 'black')
ax2.set_facecolor('gainsboro')

# %%
df_2012.head()
# Out:
#                  Circuit  Leading Score  VET Score  ALO Score Fastest Quali  \
# 0  Australian Grand Prix            0.0        0.0        0.0      1:24.922
# 1   Malaysian Grand Prix           25.0       18.0       10.0      1:36.219
# 2     Chinese Grand Prix           35.0       18.0       35.0      1:35.121
# 3     Bahrain Grand Prix           45.0       28.0       37.0      1:32.422
# 4     Spanish Grand Prix           53.0       53.0       43.0      1:21.707
#
#    P5 Quali VET Quali ALO Quali  Year  VET Quali Gap  ALO Quali Gap  VET Gap  \
# 0  1:25.651  1:25.668  1:27.024  2012          0.746          2.102      0.0
# 1  1:36.461  1:36.634  1:37.566  2012          0.415          1.347     -7.0
# 2  1:35.898  1:36.997  1:36.622  2012          1.876          1.501    -17.0
# 3  1:32.821  1:32.422  1:33.533  2012          0.000          1.111    -17.0
# 4  1:22.487  1:23.221  1:22.302  2012          1.514          0.595      0.0
#
#    ALO Gap
# 0      0.0
# 1    -15.0
# ...

# %%
df_2012[['VET Gap', 'VET Quali Gap']].corr()
# Out:
#                 VET Gap  VET Quali Gap
# VET Gap        1.000000      -0.181161
# VET Quali Gap -0.181161       1.000000

# %%
df_2012[['ALO Gap', 'ALO Quali Gap']].corr()
# Out:
#                 ALO Gap  ALO Quali Gap
# ALO Gap        1.000000      -0.150158
# ALO Quali Gap -0.150158       1.000000

# %%
#2012 Viz
fig = plt.figure(figsize=(15,25))
fig.set_facecolor('#3e3e3e')
ax1 = fig.add_subplot(4, 1, 1)
plt.plot( 'Circuit', 'VET Score', data=df_2012, marker = 'o', color='darkblue', linewidth=2)
plt.plot( 'Circuit', 'ALO Score', data=df_2012, marker = 'o', color='firebrick', linewidth=2)
plt.title('2012 F1 Championship Battle, Vettle vs. Alonso', fontsize = 24, color = 'white')
plt.xlabel('Grand Prix', fontsize = 19, color = 'white')
plt.ylabel('Championship Points', fontsize = 19, color = 'white')
ax1.legend()
plt.xticks(rotation=90, color = 'white', fontsize = 12)
plt.yticks(color = 'white')
ax1.set_facecolor('gainsboro')
ax1.grid(which = 'major', axis = 'y', linewidth = 1, color = 'white', alpha = 0.9)

ax2 = fig.add_subplot(5, 1, 3)
plt.plot( 'Circuit', 'VET Gap', data=df_2012, marker = 'o', color='darkblue', linewidth=2)
ax2.set_facecolor('gainsboro')
plt.xticks(rotation=90, color = 'white', fontsize = 12)
plt.title('Points Behind Championship Lead and Gap to Pole (VET)', fontsize = 24, color = 'white')
plt.xlabel('Grand Prix', fontsize = 19, color = 'white')
plt.ylabel('Championship Points Behind', fontsize = 12, color = 'white')
plt.yticks(color = 'white')
ax2.legend(loc = 'center left', bbox_to_anchor=(0, 0.6))
ax3 = ax2.twinx()
ax3.plot('Circuit', 'VET Quali Gap', data=df_2012, marker = 'o', color = '#FF0026')
plt.yticks(color = 'white')
plt.ylabel('Gap to Pole (in seconds)', fontsize = 12, color = 'white')
ax3.legend(loc = 'center left', bbox_to_anchor=(0, 0.52))

ax4 = fig.add_subplot(5,1,5)
plt.plot( 'Circuit', 'ALO Gap', data=df_2012, marker = 'o', color='firebrick', linewidth=2)
ax4.set_facecolor('gainsboro')
plt.xticks(rotation=90, color = 'white', fontsize = 12)
plt.title('Points Behind Championship Lead and Gap to Pole (ALO)', fontsize = 24, color = 'white')
plt.xlabel('Grand Prix', fontsize = 19, color = 'white')
plt.ylabel('Championship Points Behind', fontsize = 12, color = 'white')
plt.yticks(color = 'white')
ax4.legend(loc = 'center left', bbox_to_anchor=(0, 0.6))
ax5 = ax4.twinx()
ax5.plot('Circuit', 'ALO Quali Gap', data=df_2012, marker = 'o', color = '#FFEA00')
plt.yticks(color = 'white')
plt.ylabel('Gap to Pole (in seconds)', fontsize = 12, color = 'white')
ax5.legend(loc = 'center left', bbox_to_anchor=(0, 0.52))

# %%
#2012 Viz Continuation
fig = plt.figure(figsize = (15,9))
ax1 = fig.add_subplot(2, 2, 1)
plt.scatter(df_2012['VET Gap'], df_2012['VET Quali Gap'], color = 'darkblue')
plt.title('WDC Gap vs. Quali Gap (VET)', fontsize = 19, color = 'black')
plt.xlabel('Points behind WDC Lead', fontsize = 15, color = 'black')
plt.ylabel('Gap to Pole (in seconds)', fontsize = 15, color = 'black')
ax1.set_facecolor('gainsboro')

ax2 = fig.add_subplot(2, 2, 2)
plt.scatter(df_2012['ALO Gap'], df_2012['ALO Quali Gap'], color = 'firebrick')
plt.title('WDC Gap vs. Quali Gap (ALO)', fontsize = 19, color = 'black')
plt.xlabel('Points behind WDC Lead', fontsize = 15, color = 'black')
plt.ylabel('Gap to Pole (in seconds)', fontsize = 15, color = 'black')
ax2.set_facecolor('gainsboro')

# %%
df_2016.head()
# Out:
#                  Circuit  Leading Score  ROS Score  HAM2 Score Fastest Quali  \
# 0  Australian Grand Prix            0.0        0.0         0.0      1:23.837
# 1     Bahrain Grand Prix           25.0       25.0        18.0      1:29.493
# 2     Chinese Grand Prix           50.0       50.0        33.0      1:35.402
# 3     Russian Grand Prix           75.0       75.0        39.0      1:35.417
# 4     Spanish Grand Prix          100.0      100.0        57.0      1:22.000
#
#    P5 Quali ROS Quali HAM2 Quali  ROS Quali Gap  HAM2 Quali Gap  ROS Gap  \
# 0  1:25.434  1:24.197   1:23.837          0.360             0.0      0.0
# 1  1:30.854  1:29.570   1:29.493          0.077             0.0      0.0
# 2  1:36.296  1:35.402       None          0.000             NaN      0.0
# 3  1:37.016  1:35.417       None          0.000             NaN      0.0
# 4  1:23.113  1:22.280   1:22.000          0.280             0.0      0.0
#
#    HAM2 Gap
# 0       0.0
# 1      -7.0
# 2     -17.0
# ...

# %%
#2016 Viz
fig = plt.figure(figsize=(15,25))
fig.set_facecolor('#3e3e3e')
ax1 = fig.add_subplot(4, 1, 1)
plt.plot( 'Circuit', 'ROS Score', data=df_2016, marker = 'o', color='darkgray', linewidth=2)
plt.plot( 'Circuit', 'HAM2 Score', data=df_2016, marker = 'o', color='black', linewidth=2)
plt.title('2016 F1 Championship Battle, Rosberg vs. Hamilton', fontsize = 24, color = 'white')
plt.xlabel('Grand Prix', fontsize = 19, color = 'white')
plt.ylabel('Championship Points', fontsize = 19, color = 'white')
ax1.legend()
plt.xticks(rotation=90, color = 'white', fontsize = 12)
plt.yticks(color = 'white')
ax1.set_facecolor('gainsboro')
ax1.grid(which = 'major', axis = 'y', linewidth = 1, color = 'white', alpha = 0.9)

ax2 = fig.add_subplot(5, 1, 3)
plt.plot( 'Circuit', 'ROS Gap', data=df_2016, marker = 'o', color='darkgray', linewidth=2)
ax2.set_facecolor('gainsboro')
plt.xticks(rotation=90, color = 'white', fontsize = 12)
plt.title('Points Behind Championship Lead and Gap to Pole (ROS)', fontsize = 24, color = 'white')
plt.xlabel('Grand Prix', fontsize = 19, color = 'white')
plt.ylabel('Championship Points Behind', fontsize = 12, color = 'white')
plt.yticks(color = 'white')
ax2.legend(loc = 'center left', bbox_to_anchor=(0, 0.8))
ax3 = ax2.twinx()
ax3.plot('Circuit', 'ROS Quali Gap', data=df_2016, marker = 'o', color = '#03BFB5')
plt.yticks(color = 'white')
plt.ylabel('Gap to Pole (in seconds)', fontsize = 12, color = 'white')
ax3.legend(loc = 'center left', bbox_to_anchor=(0, 0.72))

ax4 = fig.add_subplot(5,1,5)
plt.plot( 'Circuit', 'HAM2 Gap', data=df_2016, marker = 'o', color='black', linewidth=2)
ax4.set_facecolor('gainsboro')
plt.xticks(rotation=90, color = 'white', fontsize = 12)
plt.title('Points Behind Championship Lead and Gap to Pole (HAM)', fontsize = 24, color = 'white')
plt.xlabel('Grand Prix', fontsize = 19, color = 'white')
plt.ylabel('Championship Points Behind', fontsize = 12, color = 'white')
plt.yticks(color = 'white')
ax4.legend(loc = 'center left', bbox_to_anchor=(0, 0.5))
ax5 = ax4.twinx()
ax5.plot('Circuit', 'HAM2 Quali Gap', data=df_2016, marker = 'o', color = '#018076')
plt.yticks(color = 'white')
plt.ylabel('Gap to Pole (in seconds)', fontsize = 12, color = 'white')
ax5.legend(loc = 'center left', bbox_to_anchor=(0, 0.42))

# %%
#2008 Viz Continuation
fig = plt.figure(figsize = (15,9))
ax1 = fig.add_subplot(2, 2, 1)
plt.scatter(df_2016['ROS Gap'], df_2016['ROS Quali Gap'], color = 'darkgray')
plt.title('WDC Gap vs. Quali Gap (ROS)', fontsize = 19, color = 'black')
plt.xlabel('Points behind WDC Lead', fontsize = 15, color = 'black')
plt.ylabel('Gap to Pole (in seconds)', fontsize = 15, color = 'black')
ax1.set_facecolor('gainsboro')

ax2 = fig.add_subplot(2, 2, 2)
plt.scatter(df_2016['HAM2 Gap'], df_2016['HAM2 Quali Gap'], color = 'black')
plt.title('WDC Gap vs. Quali Gap (HAM)', fontsize = 19, color = 'black')
plt.xlabel('Points behind WDC Lead', fontsize = 15, color = 'black')
plt.ylabel('Gap to Pole (in seconds)', fontsize = 15, color = 'black')
ax2.set_facecolor('gainsboro')

# %%
df_2016[['ROS Gap', 'ROS Quali Gap']].corr()
# Out:
#                 ROS Gap  ROS Quali Gap
# ROS Gap        1.000000       0.110982
# ROS Quali Gap  0.110982       1.000000

# %%
df_2016[['HAM2 Gap', 'HAM2 Quali Gap']].corr()
# Out:
#                 HAM2 Gap  HAM2 Quali Gap
# HAM2 Gap        1.000000        0.122503
# HAM2 Quali Gap  0.122503        1.000000
