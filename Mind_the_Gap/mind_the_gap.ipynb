# %%
import pandas as pd
import requests
from datetime import datetime

# %%
response2008 = []
for i in range(1, 19):
    link = 'http://ergast.com/api/f1/2008/' + str(i) + '/driverStandings.json'
    response2008.append(requests.get(link).json())
lead_score = [0]
HAM_score = [0]
MAS_score = [0,0,0]

for response in response2008:
    lead_score.append(response['MRData']['StandingsTable']['StandingsLists'][0]['DriverStandings'][0]['points'])
    for standing in response['MRData']['StandingsTable']['StandingsLists'][0]['DriverStandings']:
        if standing['Driver']['code'] == "HAM":
            HAM_score.append(standing['points'])
        if standing['Driver']['code'] == "MAS":
            MAS_score.append(standing['points'])


response2008quali = []
for i in range(1, 19):
    link = 'http://ergast.com/api/f1/2008/' + str(i) + '/qualifying.json'
    response2008quali.append(requests.get(link).json())
circuit08 = []
lead_quali08 = []
P5 = []
HAM_quali = []
MAS_quali = []
for response in response2008quali:
    circuit08.append(response['MRData']['RaceTable']['Races'][0]['raceName'])
    lead_quali08.append(response['MRData']['RaceTable']['Races'][0]['QualifyingResults'][0]['Q3'])
    P5.append(response['MRData']['RaceTable']['Races'][0]['QualifyingResults'][4]['Q3']) #Q2
    for quali in response['MRData']['RaceTable']['Races'][0]['QualifyingResults']:
        if quali['Driver']['code'] == 'MAS':
            if 'Q3' in quali:
                MAS_quali.append(quali['Q3'])
            else:
                MAS_quali.append(100)
        if quali['Driver']['code'] == 'HAM':
            if 'Q3' in quali:
                HAM_quali.append(quali['Q3'])
            else:
                HAM_quali.append(int(quali['position']))

df_2008 = pd.DataFrame(list(zip(circuit08, lead_score, HAM_score, MAS_score, lead_quali08, P5, HAM_quali, MAS_quali)), columns = ['Circuit', 'Leading Score', 'HAM Score', 'MAS Score', 'Fastest Quali', 'P5 Quali', 'HAM Quali', 'MAS Quali'])
df_2008['Year'] = 2008
df_2008.head(18)
# Out:
#                   Circuit Leading Score HAM Score MAS Score Fastest Quali  \
# 0   Australian Grand Prix             0         0         0      1:26.714
# 1    Malaysian Grand Prix            10        10         0      1:35.748
# 2      Bahrain Grand Prix            14        14         0      1:33.096
# 3      Spanish Grand Prix            19        14        10      1:21.813
# 4      Turkish Grand Prix            29        20        18      1:27.617
# 5       Monaco Grand Prix            35        28        28      1:15.787
# 6     Canadian Grand Prix            38        38        34      1:17.886
# 7       French Grand Prix            42        38        38      1:16.449
# 8      British Grand Prix            48        38        48      1:21.049
# 9       German Grand Prix            48        48        48      1:15.666
# 10   Hungarian Grand Prix            58        58        54      1:20.899
# 11    European Grand Prix            62        62        54      1:38.989
# ...

# %%
response2012 = []
for i in range(1, 21):
    link = 'http://ergast.com/api/f1/2012/' + str(i) + '/driverStandings.json'
    response2012.append(requests.get(link).json())
lead_score12 = [0]
VET_score = [0]
ALO_score = [0]

for response in response2012:
    lead_score12.append(response['MRData']['StandingsTable']['StandingsLists'][0]['DriverStandings'][0]['points'])
    for standing in response['MRData']['StandingsTable']['StandingsLists'][0]['DriverStandings']:
        if standing['Driver']['code'] == "VET":
            VET_score.append(standing['points'])
        if standing['Driver']['code'] == "ALO":
            ALO_score.append(standing['points'])


response2012quali = []
for i in range(1, 21):
    link = 'http://ergast.com/api/f1/2012/' + str(i) + '/qualifying.json'
    response2012quali.append(requests.get(link).json())
circuit12 = []
lead_quali12 = []
P5_2012 = []
VET_quali = []
ALO_quali = []
for response in response2012quali:
    circuit12.append(response['MRData']['RaceTable']['Races'][0]['raceName'])
    lead_quali12.append(response['MRData']['RaceTable']['Races'][0]['QualifyingResults'][0]['Q3'])
    P5_2012.append(response['MRData']['RaceTable']['Races'][0]['QualifyingResults'][4]['Q3']) #Q2
    for quali in response['MRData']['RaceTable']['Races'][0]['QualifyingResults']:
        if quali['Driver']['code'] == 'VET':
            if 'Q3' in quali:
                VET_quali.append(quali['Q3'])
            else:
                VET_quali.append(int(quali['position']))

        if quali['Driver']['code'] == 'ALO':
            if 'Q3' in quali:
                ALO_quali.append(quali['Q3'])
            else:
                #ALO_quali.append(100)
                ALO_quali.append(int(quali['position']))


df_2012 = pd.DataFrame(list(zip(circuit12, lead_score12, VET_score, ALO_score, lead_quali12, P5_2012, VET_quali, ALO_quali)), columns = ['Circuit', 'Leading Score', 'VET Score', 'ALO Score', 'Fastest Quali', 'P5 Quali', 'VET Quali', 'ALO Quali'])
df_2012['Year'] = 2012
df_2012.head(20)
# Out:
#                      Circuit Leading Score VET Score ALO Score Fastest Quali  \
# 0      Australian Grand Prix             0         0         0      1:24.922
# 1       Malaysian Grand Prix            25        18        10      1:36.219
# 2         Chinese Grand Prix            35        18        35      1:35.121
# 3         Bahrain Grand Prix            45        28        37      1:32.422
# 4         Spanish Grand Prix            53        53        43      1:21.707
# 5          Monaco Grand Prix            61        61        61      1:14.301
# 6        Canadian Grand Prix            76        73        76      1:13.784
# 7        European Grand Prix            88        85        86      1:38.086
# 8         British Grand Prix           111        85       111      1:51.746
# 9          German Grand Prix           129       100       129      1:40.621
# 10      Hungarian Grand Prix           154       110       154      1:20.953
# ...

# %%
response2016 = []
for i in range(1, 22):
    link = 'http://ergast.com/api/f1/2016/' + str(i) + '/driverStandings.json'
    response2016.append(requests.get(link).json())
lead_score16 = [0]
ROS_score = [0]
HAM2_score = [0]

for response in response2016:
    lead_score16.append(response['MRData']['StandingsTable']['StandingsLists'][0]['DriverStandings'][0]['points'])
    for standing in response['MRData']['StandingsTable']['StandingsLists'][0]['DriverStandings']:
        if standing['Driver']['code'] == "ROS":
            ROS_score.append(standing['points'])
        if standing['Driver']['code'] == "HAM":
            HAM2_score.append(standing['points'])


response2016quali = []
for i in range(1, 22):
    link = 'http://ergast.com/api/f1/2016/' + str(i) + '/qualifying.json'
    response2016quali.append(requests.get(link).json())
circuit16 = []
lead_quali16 = []
ROS_quali = []
HAM2_quali = []
for response in response2016quali:
    circuit16.append(response['MRData']['RaceTable']['Races'][0]['raceName'])
    lead_quali16.append(response['MRData']['RaceTable']['Races'][0]['QualifyingResults'][0]['Q3'])
    for quali in response['MRData']['RaceTable']['Races'][0]['QualifyingResults']:
        if quali['Driver']['code'] == 'ROS':
            if 'Q3' in quali:
                ROS_quali.append(quali['Q3'])
            else:
                ROS_quali.append(100)
        if quali['Driver']['code'] == 'HAM':
            if 'Q3' in quali:
                HAM2_quali.append(quali['Q3'])
            else:
                HAM2_quali.append(100)

df_2016 = pd.DataFrame(list(zip(circuit16, lead_score16, ROS_score, HAM2_score, lead_quali16, ROS_quali, HAM2_quali)), columns = ['Circuit', 'Leading Score', 'ROS Score', 'HAM2 Score', 'Fastest Quali', 'ROS Quali', 'HAM2 Quali'])
df_2016.head(21)
# Out:
#                      Circuit Leading Score ROS Score HAM2 Score Fastest Quali  \
# 0      Australian Grand Prix             0         0          0      1:23.837
# 1         Bahrain Grand Prix            25        25         18      1:29.493
# 2         Chinese Grand Prix            50        50         33      1:35.402
# 3         Russian Grand Prix            75        75         39      1:35.417
# 4         Spanish Grand Prix           100       100         57      1:22.000
# 5          Monaco Grand Prix           100       100         57      1:13.622
# 6        Canadian Grand Prix           106       106         82      1:12.812
# 7        European Grand Prix           116       116        107      1:42.758
# 8        Austrian Grand Prix           141       141        117      1:07.922
# 9         British Grand Prix           153       153        142      1:29.287
# 10      Hungarian Grand Prix           168       168        167      1:19.965
# ...

# %%
def dt_to_int(time):
    return 1000*time.seconds + time.milliseconds

# %%
df_2008['Leading Score'] = df_2008['Leading Score'].astype(float)
df_2008['HAM Score'] = df_2008['HAM Score'].astype(float)
df_2008['MAS Score'] = df_2008['MAS Score'].astype(float)
# df_2008['Fastest Quali'] = pd.to_datetime(df_2008['Fastest Quali'], format='%H:%M:%S.%f').dt.time
# df_2008['MAS Quali'] = pd.to_datetime(df_2008['MAS Quali'], format='%H:%M:%S.%f')
# df_2008['MAS Quali'] - dt_to_int(df_2008['MAS Quali'])
MAS_Quali_Gap = []
for i in range(len(df_2008)):
    MAS_Quali_Gap.append(datetime.strptime(df_2008['MAS Quali'][i], '%M:%S.%f') - datetime.strptime(df_2008['Fastest Quali'][i], '%M:%S.%f'))
#df_2008['MAS Quali Gap'] = datetime.strptime(df_2008['MAS Quali'], '%M:%S.%f') - datetime.strptime(df_2008['Fastest Quali'], '%M:%S.%f')
df_2008['MAS Quali Gap'] = MAS_Quali_Gap
# df_2008['HAM Gap'] = df_2008['Leading Score'] - df_2008['HAM Score']
# df_2008['MAS Gap'] = df_2008['Leading Score'] - df_2008['MAS Score']
# df_2008['HAM Quali Gap'] = df_2008['Fastest Quali'] - df_2008['HAM Quali']
# df_2008['MAS Quali Gap'] = df_2008['Fastest Quali'] - df_2008['MAS Quali']
# df_2008['MAS Quali Gap'] = (pd.to_datetime(df_2008['MAS Quali'].astype(str), format='%H:%M:%S.%f') -
#    pd.to_datetime(df_2008['Fastest Quali'].astype(str), format='%H:%M:%S.%f')).dt.time

# df_2012['VET Gap'] = df_2012['Leading Score'] - df_2012['VET Score']
# df_2012['ALO Gap'] = df_2012['Leading Score'] - df_2012['ALO Score']
# df_2012['VET Quali Gap'] = df_2012['Fastest Quali'] - df_2012['VET Quali']
# df_2012['ALO Quali Gap'] = df_2012['Fastest Quali'] - df_2012['ALO Quali']

# df_2016['ROS Gap'] = df_2016['Leading Score'] - df_2016['ROS Score']
# df_2016['HAM2 Gap'] = df_2016['Leading Score'] - df_2016['HAM2 Score']
# df_2016['ROS Quali Gap'] = df_2016['Fastest Quali'] - df_2016['ROS Quali']
# df_2016['HAM2 Quali Gap'] = df_2016['Fastest Quali'] - df_2016['HAM2 Quali']

# %%
df_2008['MAS Quali Gap'] = df_2008['MAS Quali Gap'].dt.total_seconds()

# %%
df_2008.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Circuit        18 non-null     object
#  1   Leading Score  18 non-null     float64
#  2   HAM Score      18 non-null     float64
#  3   MAS Score      18 non-null     float64
#  4   Fastest Quali  18 non-null     object
#  5   HAM Quali      18 non-null     object
#  6   MAS Quali      18 non-null     object
#  7   Year           18 non-null     int64
#  8   MAS Quali Gap  18 non-null     float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 1.4+ KB
